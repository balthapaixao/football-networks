# %%
import numpy as np
import pandas as pd

from statsbombpy import sb

# %%
MATCH_ID = 3888705
df = sb.events(MATCH_ID)

df.sample(5)
# Out:
#      50_50 ball_receipt_outcome ball_recovery_offensive  \
# 2758   NaN                  NaN                     NaN
# 3203   NaN                  NaN                     NaN
# 1842   NaN                  NaN                     NaN
# 1005   NaN           Incomplete                     NaN
# 1472   NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection block_offensive  \
# 2758                            NaN              NaN             NaN
# 3203                            NaN              NaN             NaN
# 1842                            NaN              NaN             NaN
# 1005                            NaN              NaN             NaN
# 1472                            NaN              NaN             NaN
#
#      carry_end_location clearance_aerial_won clearance_body_part  \
# 2758                NaN                  NaN                 NaN
# 3203                NaN                  NaN                 NaN
# 1842       [72.4, 45.5]                  NaN                 NaN
# 1005                NaN                  NaN                 NaN
# 1472                NaN                  NaN                 NaN
#
#      clearance_head  ... shot_outcome shot_statsbomb_xg shot_technique  \
# 2758            NaN  ...          NaN               NaN            NaN
# 3203            NaN  ...          NaN               NaN            NaN
# 1842            NaN  ...          NaN               NaN            NaN
# 1005            NaN  ...          NaN               NaN            NaN
# 1472            NaN  ...          NaN               NaN            NaN
#
#      shot_type tactics    team team_id     timestamp           type  \
# 2758       NaN     NaN  Brazil     781  00:20:07.774       Pressure
# 3203       NaN     NaN  Sweden     790  00:33:13.920  Ball Recovery
# 1842       NaN     NaN  Sweden     790  00:16:17.016          Carry
# 1005       NaN     NaN  Sweden     790  00:06:56.918  Ball Receipt*
# 1472       NaN     NaN  Brazil     781  00:15:17.963  Ball Receipt*
#
#      under_pressure
# 2758            NaN
# 3203            NaN
# 1842           True
# 1005           True
# 1472            NaN
#
# [5 rows x 88 columns]

# %%
class AnnotationHandler(HandlerLine2D):
    """
    Copied this from https://stackoverflow.com/a/49262926

    Useful to add a annotation entry to legend since it is not
    automatically added
    """

    def __init__(self, ms, *args, **kwargs):
        self.ms = ms
        HandlerLine2D.__init__(self, *args, **kwargs)

    def create_artists(
        self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans
    ):
        xdata, _ = self.get_xdata(legend, xdescent, ydescent, width, height, fontsize)
        ydata = ((height - ydescent) / 2.0) * np.ones(np.array(xdata).shape, float)
        legline = FancyArrowPatch(
            posA=(xdata[0], ydata[0]),
            posB=(xdata[-1], ydata[-1]),
            mutation_scale=self.ms,
            **orig_handle.arrowprops
        )
        legline.set_transform(trans)
        return (legline,)


def add_arrow(x1, y1, x2, y2, ax, **kwargs):
    """
    Helper function to add an arrow b/w two points
    defined by (x1,y1) and (x2, y2)

    A line is drawn from point A to point B. An arrow is then drawn from point A along halfway to point B. This is an easy way to get an arrow with a head in the middle
    """
    ax.plot([x1, x2], [y1, y2], **kwargs)

    annotation = ax.annotate(
        "",
        xytext=(x1, y1),
        xy=(x1 + ((x2 - x1) / 2), y1 + ((y2 - y1) / 2)),
        arrowprops=dict(arrowstyle="->", **kwargs),
        zorder=10,
        size=30,
        label="Darker color indicates higher number of passes in that direction",
    )

    return annotation
